# %%
# numpy and pandas for data manipulation
import numpy as np
import pandas as pd 

# sklearn preprocessing for dealing with categorical variables
from sklearn.preprocessing import LabelEncoder

# File system manangement
import os


# matplotlib and seaborn for plotting
import matplotlib.pyplot as plt
import seaborn as sns 

windows_dir = "../kaggle/all/"
ubuntu_dir = "/home/prof/kaggle/unbankedcredit/kaggle/all/"

import platform

system = platform.system()

print("Notebook is running on operating system: {}".format(system))
if system == "Linux":
    directory = ubuntu_dir
else:
    directory = windows_dir
# Out:
# Notebook is running on operating system: Linux

# %%
# Bureau data
app_bur_file = "{}bureau.csv".format(directory)
app_bur = pd.read_csv(app_bur_file)
print('Training data shape: ', app_bur.shape)
app_bur.describe()
# Out:
# Training data shape:  (1716428, 17)
#          SK_ID_CURR  SK_ID_BUREAU   DAYS_CREDIT  CREDIT_DAY_OVERDUE  \
# count  1.716428e+06  1.716428e+06  1.716428e+06        1.716428e+06
# mean   2.782149e+05  5.924434e+06 -1.142108e+03        8.181666e-01
# std    1.029386e+05  5.322657e+05  7.951649e+02        3.654443e+01
# min    1.000010e+05  5.000000e+06 -2.922000e+03        0.000000e+00
# 25%    1.888668e+05  5.463954e+06 -1.666000e+03        0.000000e+00
# 50%    2.780550e+05  5.926304e+06 -9.870000e+02        0.000000e+00
# 75%    3.674260e+05  6.385681e+06 -4.740000e+02        0.000000e+00
# max    4.562550e+05  6.843457e+06  0.000000e+00        2.792000e+03
#
#        DAYS_CREDIT_ENDDATE  DAYS_ENDDATE_FACT  AMT_CREDIT_MAX_OVERDUE  \
# count         1.610875e+06       1.082775e+06            5.919400e+05
# mean          5.105174e+02      -1.017437e+03            3.825418e+03
# std           4.994220e+03       7.140106e+02            2.060316e+05
# ...

# %%
app_bur.head()
# Out:
#    SK_ID_CURR  SK_ID_BUREAU CREDIT_ACTIVE CREDIT_CURRENCY  DAYS_CREDIT  \
# 0      215354       5714462        Closed      currency 1         -497
# 1      215354       5714463        Active      currency 1         -208
# 2      215354       5714464        Active      currency 1         -203
# 3      215354       5714465        Active      currency 1         -203
# 4      215354       5714466        Active      currency 1         -629
#
#    CREDIT_DAY_OVERDUE  DAYS_CREDIT_ENDDATE  DAYS_ENDDATE_FACT  \
# 0                   0               -153.0             -153.0
# 1                   0               1075.0                NaN
# 2                   0                528.0                NaN
# 3                   0                  NaN                NaN
# 4                   0               1197.0                NaN
#
#    AMT_CREDIT_MAX_OVERDUE  CNT_CREDIT_PROLONG  AMT_CREDIT_SUM  \
# 0                     NaN                   0         91323.0
# ...

# %%
app_bur[app_bur['SK_ID_CURR'] == 100007]
# Out:
#          SK_ID_CURR  SK_ID_BUREAU CREDIT_ACTIVE CREDIT_CURRENCY  DAYS_CREDIT  \
# 1503966      100007       5987200        Closed      currency 1        -1149
#
#          CREDIT_DAY_OVERDUE  DAYS_CREDIT_ENDDATE  DAYS_ENDDATE_FACT  \
# 1503966                   0               -783.0             -783.0
#
#          AMT_CREDIT_MAX_OVERDUE  CNT_CREDIT_PROLONG  AMT_CREDIT_SUM  \
# 1503966                     0.0                   0        146250.0
#
#          AMT_CREDIT_SUM_DEBT  AMT_CREDIT_SUM_LIMIT  AMT_CREDIT_SUM_OVERDUE  \
# 1503966                  0.0                   0.0                     0.0
#
#              CREDIT_TYPE  DAYS_CREDIT_UPDATE  AMT_ANNUITY
# 1503966  Consumer credit                -783          NaN

# %%
app_bur.head(10)
# Out:
#    SK_ID_CURR  SK_ID_BUREAU CREDIT_ACTIVE CREDIT_CURRENCY  DAYS_CREDIT  \
# 0      215354       5714462        Closed      currency 1         -497
# 1      215354       5714463        Active      currency 1         -208
# 2      215354       5714464        Active      currency 1         -203
# 3      215354       5714465        Active      currency 1         -203
# 4      215354       5714466        Active      currency 1         -629
# 5      215354       5714467        Active      currency 1         -273
# 6      215354       5714468        Active      currency 1          -43
# 7      162297       5714469        Closed      currency 1        -1896
# 8      162297       5714470        Closed      currency 1        -1146
# 9      162297       5714471        Active      currency 1        -1146
#
#    CREDIT_DAY_OVERDUE  DAYS_CREDIT_ENDDATE  DAYS_ENDDATE_FACT  \
# 0                   0               -153.0             -153.0
# ...

# %%
app_bur.groupby(["SK_ID_CURR", "CREDIT_ACTIVE"]).size()
# Out:
# SK_ID_CURR  CREDIT_ACTIVE
# 100001      Active            3
#             Closed            4
# 100002      Active            2
#             Closed            6
# 100003      Active            1
#             Closed            3
# 100004      Closed            2
# 100005      Active            2
#             Closed            1
# 100007      Closed            1
# 100008      Active            1
#             Closed            2
# 100009      Active            4
#             Closed           14
# 100010      Active            1
#             Closed            1
# 100011      Closed            4
# 100013      Closed            4
# 100014      Active            2
#             Closed            6
# 100015      Closed            4
# 100016      Active            4
#             Closed            3
# 100017      Closed            6
# 100019      Active            2
# 100020      Active            2
#             Closed            2
# 100022      Active            2
# ...

# %%
app_bur['TOTAL_OUTSTANDING_DEBT'] = app_bur.groupby(["SK_ID_CURR"])["AMT_CREDIT_SUM_DEBT"].transform(sum)

# %%
app_bur[['SK_ID_CURR','TOTAL_OUTSTANDING_DEBT']].tail(30)
# Out:
#          SK_ID_CURR  TOTAL_OUTSTANDING_DEBT
# 1716398      312021                   0.000
# 1716399      232638              886297.500
# 1716400      318662              397102.500
# 1716401      145715              119902.500
# 1716402      352358               66344.625
# 1716403      361928             2996973.000
# 1716404      166279              432787.500
# 1716405      438109              300849.660
# 1716406      335468                   0.000
# 1716407      146896              316732.500
# 1716408      146896              316732.500
# 1716409      146896              316732.500
# 1716410      280228              213885.000
# 1716411      232118              151216.650
# 1716412      288038              307821.600
# 1716413      288038              307821.600
# 1716414      445222              328766.985
# 1716415      317217             2075129.100
# 1716416      433007             1261621.665
# 1716417      433007             1261621.665
# ...

# %%
app_bur.drop_duplicates(subset='SK_ID_CURR', keep='first', inplace=True)

# %%
app_bur = app_bur[['SK_ID_CURR', 'TOTAL_OUTSTANDING_DEBT']]

# %%
app_bur.head()
# Out:
#     SK_ID_CURR  TOTAL_OUTSTANDING_DEBT
# 0       215354               284463.18
# 7       162297                    0.00
# 13      402440                76905.00
# 14      238881               552730.50
# 21      222183              1185081.84

# %%
app_bur.to_csv("outstanding.csv", index = False)
